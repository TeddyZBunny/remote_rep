# %%
summer=True 

if summer:
    print('The good weather')
else:
    print('The weather is bad')
# Out:
# A good weather

# %%
a = 'Today is Tuesday'

if a:
    print('...')
    
b = ''   
if b:
    print('...')
    
# Отсутствие значения - это False. None - False. 0 - тоже False
# Out:
# ...

# %%
nums =[1,5,3,63,4,5,343,345]
print(max(nums))

a=1/3
print(round(a,3)) # Округление

print(abs(-1)) # Значение по модулю

print(sorted(nums))
print(sorted(nums,reverse=True))

print()
nums.sort()
print(nums)

print()
nums.sort(reverse=True)
print(nums)
# Out:
# 345
# 0.333
# 1
# [1, 3, 4, 5, 5, 63, 343, 345]
# [345, 343, 63, 5, 5, 4, 3, 1]
#
# [1, 3, 4, 5, 5, 63, 343, 345]
#
# [345, 343, 63, 5, 5, 4, 3, 1]

# %%
#MAP, mapping - сопоставление данных с объектов и т.п.
sml=[1,2,34,35,4,235,43]

print()
sml1=[]
for x in sml:
    sml1.append(x*2)
print(sml1)
print()

sml2=[]
def mult_2(a):
    return a*2

sml2=map(mult_2,sml)
print(list(sml2))       # list - возвращает в формате листа массив, если хотим распечатать например, или хотим создать лист
# Out:
# [2, 4, 68, 70, 8, 470, 86]
#
# [2, 4, 68, 70, 8, 470, 86]

# %%
name, surname = input('What is your name?').split()
print(f'My name is {name} {surname}')
# Out:
# My name is aef adsf

# %%
code, floor = map(int, input('What is code from your door and what floor?').split())
print(f'My code is {code} and floor is {floor}')
# Out:
# My code is 1234 and floor is 3

# %%
sml=[1,2,34,35,4,235,43]

sml2=map(lambda x: x*2,sml) # Первая лямбда функция
print(list(sml2))
# Out:
# [2, 4, 68, 70, 8, 470, 86]
