# %%
import datetime
time_now=datetime.datetime.now()

print(time_now)
print(time_now.hour)
print(time_now.year)
print(time_now.weekday())
print(time_now.isoweekday())
print(time_now.timestamp())
print()

def add_text(func):
    def wrapper():
        print('Before functioon')
        func()
        print('after functioon')
    return wrapper
        
@add_text
def simple():
    print('Text writing function')
    
simple()
# Out:
# 2025-11-12 18:14:32.277370
# 18
# 2025
# 2
# 3
# 1762956872.27737
#
# Before functioon
# Text writing function
# after functioon
