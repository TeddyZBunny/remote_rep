# %%
import datetime
time_now=datetime.datetime.now()

print(time_now)
print(time_now.hour)
print(time_now.year)
print(time_now.weekday())
print(time_now.isoweekday())
print(time_now.timestamp())
print()

def add_text(func):
    def wrapper():
        print('Before functioon')
        func()
        print('after functioon')
    return wrapper
        
@add_text
def simple():
    print('Text writing function')
    
simple()
# Out:
# 2025-11-05 21:26:40.246858
# 21
# 2025
# 2
# 3
# 1762363600.246858
#
# Before functioon
# Text writing function
# after functioon
