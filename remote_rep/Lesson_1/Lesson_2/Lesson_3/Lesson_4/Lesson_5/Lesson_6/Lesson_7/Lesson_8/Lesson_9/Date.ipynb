# %%
import datetime
time_now=datetime.datetime.now()

print(time_now)
print(time_now.hour)
print(time_now.year)
print(time_now.weekday())
print(time_now.isoweekday())
print(time_now.timestamp())
# Out:
# 2025-10-27 14:17:16.206754
# 14
# 2025
# 0
# 1
# 1761563836.206754

# %%
mydate=datetime.datetime(1360,1,15)
print(mydate)
print(mydate.isoformat())
# Out:
# 1360-01-15 00:00:00
# 1360-01-15T00:00:00
